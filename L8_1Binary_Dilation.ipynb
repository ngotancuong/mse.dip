# %% [markdown]
# <a href="https://colab.research.google.com/github/ngotancuong/mse.dip/blob/main/L8_1Binary_Dilation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import urllib.request
import matplotlib.pyplot as plt

# load image from URL
url = 'https://raw.githubusercontent.com/ngotancuong/mse.dip/main/images/traces.png'
req = urllib.request.urlopen(url)
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
Img = cv2.imdecode(arr, -1)

# perform dilation with different structuring element (SE)
# a. Small disk with radius = 10
se1 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (10, 10))
BW1 = cv2.dilate(Img, se1, iterations=1)
# b. Large disk with radius = 25
se2 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (25, 25))
BW2 = cv2.dilate(Img, se2, iterations=1)

# show and save images
fig, axs = plt.subplots(1, 3, figsize=(10, 10))
axs[0].imshow(cv2.cvtColor(Img, cv2.COLOR_BGR2RGB))
axs[0].set_title('Original Image')
axs[1].imshow(cv2.cvtColor(BW1, cv2.COLOR_BGR2RGB))
axs[1].set_title('Dilation by Small Disk')
axs[2].imshow(cv2.cvtColor(BW2, cv2.COLOR_BGR2RGB))
axs[2].set_title('Dilation by Large Disk')
for ax in axs:
    ax.axis('off')
plt.savefig('Dilation.png', dpi=300)
plt.show()

# save images
cv2.imwrite('Dilation_Disk_10.png', BW1)
cv2.imwrite('Dilation_Disk_25.png', BW2)
# Out:
# True
